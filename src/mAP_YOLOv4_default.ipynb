# %%
# para comprobar version CUDA y tarjeta grafica asignada
# !nvidia-smi
# !nvcc --version

# %%
# clonacion del repo
# !git clone https://github.com/AlexeyAB/darknet

# %%
# %cd darknet

# change makefile to have GPU and OPENCV enabled
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# !sed -i 's/# ARCH= -gencode arch=compute_75/ARCH= -gencode arch=compute_75/' Makefile
# !make

# %%
# !mkdir images
# %cd images

# %%
# !wget -c http://images.cocodataset.org/zips/train2017.zip
# !unzip -q train2017.zip
# !rm train2017.zip

# %%
# !wget -c http://images.cocodataset.org/zips/val2017.zip
# !unzip -q val2017.zip
# !rm val2017.zip

# %%
# %cd ..

# %% [markdown]
# En el siguiente link: https://drive.google.com/drive/folders/1KyJc_FKqQwndRyEF8bVNiUbUWTLEojU0 se encuentran los ficheros ```train2017.txt``` y ```val2017.txt``` que contienen las rutas donde se encuentran almacenadas las imágenes de entrenamiento y validación y la carpeta ```./labels``` donde se encuentran las etiquetas.
#
# Copiar ficheros ```train2017.txt``` y ```val2017.txt``` dentro de la carpeta ```./data```.
#
# Copiar los ficheros de las etiquetas de las imágenes de entrenamiento que se encuentran dentro de la carpeta ```./labels/train2017``` y pegar dentro de la carpeta ```./images/train2017``` del repositorio Darknet.
#
# Del mismo modo, copiar los ficheros de las etiquetas de las imágenes de entrenamiento que se encuentran dentro de la carpeta ```./labels/val2017``` y pegar dentro de la carpeta .```/images/val2017``` del repositorio Darknet.

# %% [markdown]
# Modificar fichero coco.data:
# ```
# classes = 80
# train   = data/train2017.txt
# valid   = data/val2017.txt
# names = data/coco.names
# #backup = /home/pjreddie/backup/
# ```

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
# !./darknet detector map ./cfg/coco.data ./cfg/yolov4.cfg ./yolov4.weights
