# %%
# !nvidia-smi
# !/usr/local/cuda/bin/nvcc --version

# %%
# !git clone https://github.com/jmudy/Deep-SORT-YOLOv4-TF2

# %%
# %cd Deep-SORT-YOLOv4-TF2

# %%
# !pip3 install -r requirements.txt

# %%
# %cd Deep-SORT-YOLOv4-TF2

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights

# %%
# !python convert.py

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# %cd Deep-SORT-YOLOv4-TF2/

# %%
#!sed -i 's/GPU: NVIDIA Tesla P100/GPU: NVIDIA Tesla T4/' object_tracking-COLAB.py
#!sed -i 's/GPU: NVIDIA Tesla P100/GPU: NVIDIA Tesla P4/' object_tracking-COLAB.py
#!sed -i 's/GPU: NVIDIA Tesla P100/GPU: NVIDIA Tesla K80/' object_tracking-COLAB.py

# %%
# Modificar script object_tracking-COLAB.py insertando el path del video de entrada y de la salida (salida en Google Colab o Google Drive)
# !python object_tracking-COLAB.py

# %%
# define helper function to display videos
import io 
from IPython.display import HTML
from base64 import b64encode
def show_video(file_name, width=640):
  # show resulting deepsort video
  mp4 = open(file_name,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
  </video>
  """.format(width, data_url))

# %%
import os
path_video = os.path.join("Output","test-prueba-test.avi")
# %cd Output/
# !ffmpeg -y -loglevel panic -i test-prueba-test.avi output.mp4
# %cd ..

# output object tracking video
path_output = os.path.join("Output","output.mp4")
show_video(path_output, width=960)
