# %%
# !nvidia-smi
# !/usr/local/cuda/bin/nvcc --version

# %%
# !git clone https://github.com/jmudy/tensorflow-yolov4-tflite

# %%
# %cd tensorflow-yolov4-tflite

# %%
# !pip install -r requirements.txt

# %%
# After "You must restart the runtime in order to use newly installed versions."
# %cd tensorflow-yolov4-tflite

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights -P ./data/

# %%
# !python save_model.py --weights ./data/yolov4.weights --output ./checkpoints/yolov4-608 --input_size 608 --model yolov4

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# %cd tensorflow-yolov4-tflite

# %%
# to avoid error google colab : cannot connect to X server
# !sed -i 's/cv2.namedWindow("result", cv2.WINDOW_AUTOSIZE)/#cv2.namedWindow("result", cv2.WINDOW_AUTOSIZE)/' detect_video.py

# %%
# show and save the video in Google Colab or Google Drive

#!python detect_video.py --weights ./checkpoints/yolov4-608 --size 608 --model yolov4 --video /mydrive/videos-datasets/video1.avi --output ./detections/video1-detection.avi --dont_show
# !python detect_video.py --weights ./checkpoints/yolov4-608 --size 608 --model yolov4 --video /mydrive/videos-datasets/video5.avi --output /mydrive/results/video5-detection608.avi --dont_show

# %%
# define helper function to display videos
import io 
from IPython.display import HTML
from base64 import b64encode
def show_video(file_name, width=640):
  # show resulting deepsort video
  mp4 = open(file_name,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
  </video>
  """.format(width, data_url))

# %%
# convert resulting video from avi to mp4 file format
import os
path_video = os.path.join("detections","video1-detection.avi")
# %cd detections/
# !ffmpeg -y -loglevel panic -i video1-detection.avi output.mp4
# %cd ..

# output object tracking video
path_output = os.path.join("detections","output.mp4")
show_video(path_output, width=960)
