# %%
# !nvidia-smi
# !/usr/local/cuda/bin/nvcc --version

# %%
# Clonar el repositorio donde se encuentran los script seguimiento de objetos y el script de de detección de objetos abandonados
# !git clone https://github.com/jmudy/yolov4-deepsort

# %%
# %cd yolov4-deepsort

# %%
# Para seguimiento de objetos con Deep SORT y YOLOv4
# !git checkout develop

# Para detección de objetos abandonados con Deep SORT y YOLOv4
#!git checkout abandoned

# %%
# Checkear en que rama nos encontramos
# !git branch -a

# %%
# Con las versiones recientes de las librerías no funciona por lo que es necesario instalar versiones concretas
# !pip install -r requirements-gpu.txt

# %%
# Cuando termine de instalar las librerías y dependencias se pedirá que se reinicie el entorno de ejecución, por tanto habrá que volver a entrar a la carpeta del repositorio
# %cd yolov4-deepsort

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights -P ./data/

# %%
# !python save_model.py --weights ./data/yolov4.weights --output ./checkpoints/yolov4-608 --input_size 608 --model yolov4
#!python save_model.py --weights ./data/yolov4.weights --output ./checkpoints/yolov4-896 --input_size 896 --model yolov4

# %%
# !sed -i 's/GPU: NVIDIA GEFORCE GTX 960M/GPU: NVIDIA Tesla T4/' object_tracker.py
#!sed -i 's/GPU: NVIDIA GEFORCE GTX 960M/GPU: NVIDIA Tesla P100/' object_tracker.py
#!sed -i 's/GPU: NVIDIA GEFORCE GTX 960M/GPU: NVIDIA Tesla P4/' object_tracker.py
#!sed -i 's/GPU: NVIDIA GEFORCE GTX 960M/GPU: NVIDIA Tesla K80/' object_tracker.py

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# %cd yolov4-deepsort/

# %% [markdown]
# #Show and save the video in Google Colab or Google Drive

# %% [markdown]
# ###Video test

# %%
#!python object_tracker.py --video /mydrive/test.mp4 --output ./outputs/test-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# !python object_tracker.py --video /mydrive/test.mp4 --output /mydrive/results/test-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# %%
# !python abandoned_object.py --video /mydrive/test.mp4 --output /mydrive/results/test-abandoned608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# %% [markdown]
# ###Dataset ABODA

# %%
#!python object_tracker.py --video /mydrive/videos-datasets/video1.avi --output ./outputs/ABODA-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# !python object_tracker.py > datos.csv --video /mydrive/videos-datasets/video1.avi --output /mydrive/results/ABODA/video1-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --score 0.35

# %%
# !python abandoned_object --video /mydrive/videos-datasets/video1.avi --output /mydrive/results/ABODA-abandoned608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --score 0.35

# %% [markdown]
# ###Dataset AVSS2007

# %%
#!python object_tracker.py --video /mydrive/videos-datasets/AVSS_AB_Easy_Divx.avi --output ./outputs/AVSS_AB_Easy_Divx-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info
#!python object_tracker.py --video /mydrive/videos-datasets/AVSS_AB_Easy_Divx.avi --output /mydrive/results-AVSS_AB_Easy_Divx/AVSS_AB_Easy_Divx-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

#!python object_tracker.py > datos.csv --video /mydrive/videos-datasets/AVSSAB2007-easy-short.avi --output /mydrive/results/AVSSAB2007/AVSSAB2007-easy-short-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --iou 0.5 --score 0.75
# !python object_tracker.py --video /mydrive/videos-datasets/AVSSAB2007-easy-short.avi --output /mydrive/results/AVSSAB2007/AVSSAB2007-easy-short-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --iou 0.5 --score 0.75

#!python object_tracker.py --video /mydrive/videos-datasets/AVSSAB2007-medium-short.avi --output /mydrive/results/AVSSAB2007/AVSSAB2007-medium-short-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --score 0.25

# %%
# !python abandoned_object.py --video /mydrive/videos-datasets/AVSSAB2007-medium-short.avi --output /mydrive/results/AVSSAB2007/AVSSAB2007-medium-short-abandoned608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --score 0.25

# %% [markdown]
# ###Dataset GBA

# %%
#!python object_tracker.py --video /mydrive/videos-datasets/GBA-near-big-video2.mp4 --output ./outputs/GBA-near-big-video2-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info
# !python object_tracker.py > datos.csv --video /mydrive/videos-datasets/GBA-near-big-video2.mp4 --output /mydrive/results/GBA/GBA-near-big-video2-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --iou 0.75 --score 0.75

#!python object_tracker.py --video /mydrive/videos-datasets/GBA-near-big-video3.mp4 --output /mydrive/results/GBA/GBA-near-big-video3-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --iou 0.5 --score 0.5

# %%
# !python abandoned_object.py --video /mydrive/videos-datasets/GBA-near-big-video4.mp4 --output /mydrive/results/GBA/GBA-near-big-video4-abandoned608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info --iou 0.5 --score 0.5

# %% [markdown]
# ###Dataset PETS2007

# %%
#!python object_tracker.py --video /mydrive/videos-datasets/S08-fourthView.mp4 --output ./outputs/S08-fourthView-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# !python object_tracker.py --video /mydrive/videos-datasets/S08-fourthView.mp4 --output /mydrive/results/PETS2007/S08-fourthView-deepsort608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# %%
# !python abandoned_object.py --video /mydrive/videos-datasets/S08-fourthView.mp4 --output /mydrive/results/S08-fourthView-abandoned608.avi --model yolov4 --size 608 --weights ./checkpoints/yolov4-608 --count --dont_show --info

# %% [markdown]
# #See the results in Google Colab

# %%
# define helper function to display videos
import io 
from IPython.display import HTML
from base64 import b64encode
def show_video(file_name, width=640):
  # show resulting deepsort video
  mp4 = open(file_name,'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML("""
  <video width="{0}" controls>
        <source src="{1}" type="video/mp4">
  </video>
  """.format(width, data_url))

# %%
# convert resulting video from avi to mp4 file format
import os
path_video = os.path.join("outputs","AVSSAB2007-easy-short-deepsort608.avi")
# %cd outputs/
# !ffmpeg -y -loglevel panic -i AVSSAB2007-easy-short-deepsort608.avi output.mp4
# %cd ..

# output object tracking video
path_output = os.path.join("outputs","output.mp4")
show_video(path_output, width=960)
